# %% [markdown]
# ## Alteration on full_pubs DT column should be Document Type but it was overiden to Digital Technolgy
#
# # Done, already modified

# %%
import pandas as pd

# %%
df_nodups= pd.read_pickle("../data/dataframes/all_nodups.pkl")
df_nodups
# Out:
#         PT                                                 AU  \
# 0        J               Gusiatin, ZM; Kulikowska, D; Klik, B
# 1        J                              Vitko, TG; Suffet, IH
# 2        C                             Ntasiou, M; Andreou, E
# 3        J      Wu, LP; Zhang, SR; Chen, MM; Liu, J; Ding, XD
# 4        C                                          Staicu, D
# ...     ..                                                ...
# 2798083  C  Dieffenderfer, J; Wilkins, M; Hood, C; Beppler...
# 2798084  C  Dinesh, K; Xiong, ML; Adams, J; Dorsey, R; Sha...
# 2798085  C    Ding, CW; Heidari, S; Wang, YZ; Liu, YP; Hu, JT
# 2798086  C        Ding, CW; Li, HJ; Hu, JT; Liu, YP; Wang, YZ
# 2798087  C                                  Ding, Y; Zilic, Z
#
#                                                         AF  \
# 0        Gusiatin, Zygmunt M.; Kulikowska, Dorota; Klik...
# 1                  Vitko, Tadeo G.; Suffet, Irwin H. (Mel)
# ...

# %%
df_full = pd.read_pickle("../data/dataframes/full_pubs.pkl")
df_full
# Out:
#         PT                                                 AU  \
# 0        J               Gusiatin, ZM; Kulikowska, D; Klik, B
# 1        J                              Vitko, TG; Suffet, IH
# 2        C                             Ntasiou, M; Andreou, E
# 3        J      Wu, LP; Zhang, SR; Chen, MM; Liu, J; Ding, XD
# 4        C                                          Staicu, D
# ...     ..                                                ...
# 2798083  C  Dieffenderfer, J; Wilkins, M; Hood, C; Beppler...
# 2798084  C  Dinesh, K; Xiong, ML; Adams, J; Dorsey, R; Sha...
# 2798085  C    Ding, CW; Heidari, S; Wang, YZ; Liu, YP; Hu, JT
# 2798086  C        Ding, CW; Li, HJ; Hu, JT; Liu, YP; Wang, YZ
# 2798087  C                                  Ding, Y; Zilic, Z
#
#                                                         AF  \
# 0        Gusiatin, Zygmunt M.; Kulikowska, Dorota; Klik...
# 1                  Vitko, Tadeo G.; Suffet, Irwin H. (Mel)
# ...

# %%
# Taking DT column from all_nodups and alterating df_full DT column.

# %%
# Changing DT ==> DST to avoid confusino with DocumentType
cols = list(df_full.columns)
cols[23] = 'DST'
cols
# Out:
# ['PT',
#  'AU',
#  'AF',
#  'TI',
#  'SO',
#  'DT',
#  'DE',
#  'ID',
#  'AB',
#  'C1',
#  'RP',
#  'EM',
#  'NR',
#  'TC',
#  'Z9',
#  'PY',
#  'WC',
#  'DI',
#  'SC',
#  'UT',
#  'CN',
#  'lst_Target',
#  'SDG',
#  'DST',
#  'Intersection',
#  'Economy',
#  'Society',
#  'Environment',
#  'SDG1',
#  'SDG2',
#  'SDG3',
#  'SDG4',
#  'SDG5',
#  'SDG6',
#  'SDG7',
#  'SDG8',
#  'SDG9',
#  'SDG10',
#  'SDG11',
#  'SDG12',
#  'SDG13',
#  'SDG14',
#  'SDG15',
#  'SDG16',
#  'SDG17',
#  'additive_manufacturing',
#  'AI',
#  'big_data',
#  'blockchain',
#  'computing_infrastructure',
#  'IOT',
#  'robotics']

# %%
df_full.columns = cols
df_full
# Out:
#         PT                                                 AU  \
# 0        J               Gusiatin, ZM; Kulikowska, D; Klik, B
# 1        J                              Vitko, TG; Suffet, IH
# 2        C                             Ntasiou, M; Andreou, E
# 3        J      Wu, LP; Zhang, SR; Chen, MM; Liu, J; Ding, XD
# 4        C                                          Staicu, D
# ...     ..                                                ...
# 2798083  C  Dieffenderfer, J; Wilkins, M; Hood, C; Beppler...
# 2798084  C  Dinesh, K; Xiong, ML; Adams, J; Dorsey, R; Sha...
# 2798085  C    Ding, CW; Heidari, S; Wang, YZ; Liu, YP; Hu, JT
# 2798086  C        Ding, CW; Li, HJ; Hu, JT; Liu, YP; Wang, YZ
# 2798087  C                                  Ding, Y; Zilic, Z
#
#                                                         AF  \
# 0        Gusiatin, Zygmunt M.; Kulikowska, Dorota; Klik...
# 1                  Vitko, Tadeo G.; Suffet, Irwin H. (Mel)
# ...

# %%
dt = df_nodups[['DT', 'UT']]
dt
# Out:
#                         DT                   UT
# 0                   Review  WOS:000570328900001
# 1                  Article  WOS:000635505300001
# 2        Proceedings Paper  WOS:000410925400094
# 3                  Article  WOS:000744257400019
# 4        Proceedings Paper  WOS:000501603000009
# ...                    ...                  ...
# 2798083  Proceedings Paper  WOS:000399395700065
# 2798084  Proceedings Paper  WOS:000402630000005
# 2798085  Proceedings Paper  WOS:000390094700044
# 2798086  Proceedings Paper  WOS:000391829200039
# 2798087  Proceedings Paper  WOS:000391251700018
#
# [2798088 rows x 2 columns]

# %%
df_full2 = df_full.merge(dt, on='UT').drop(columns=['DT_x']).rename(columns={'DT_y':'DT'})
df_full2 = df_full2[cols]
df_full2
# Out:
#         PT                                                 AU  \
# 0        J               Gusiatin, ZM; Kulikowska, D; Klik, B
# 1        J                              Vitko, TG; Suffet, IH
# 2        C                             Ntasiou, M; Andreou, E
# 3        J      Wu, LP; Zhang, SR; Chen, MM; Liu, J; Ding, XD
# 4        C                                          Staicu, D
# ...     ..                                                ...
# 2798083  C  Dieffenderfer, J; Wilkins, M; Hood, C; Beppler...
# 2798084  C  Dinesh, K; Xiong, ML; Adams, J; Dorsey, R; Sha...
# 2798085  C    Ding, CW; Heidari, S; Wang, YZ; Liu, YP; Hu, JT
# 2798086  C        Ding, CW; Li, HJ; Hu, JT; Liu, YP; Wang, YZ
# 2798087  C                                  Ding, Y; Zilic, Z
#
#                                                         AF  \
# 0        Gusiatin, Zygmunt M.; Kulikowska, Dorota; Klik...
# 1                  Vitko, Tadeo G.; Suffet, Irwin H. (Mel)
# ...

# %%
df_full.NR = df_full.NR .astype(int)
df_full.lst_Target = df_full.lst_Target.astype(str)
df_full.AU = df_full.AU.astype(str)

# %%
df_full.AU.head(5)
# Out:
# 0             Gusiatin, ZM; Kulikowska, D; Klik, B
# 1                            Vitko, TG; Suffet, IH
# 2                           Ntasiou, M; Andreou, E
# 3    Wu, LP; Zhang, SR; Chen, MM; Liu, J; Ding, XD
# 4                                        Staicu, D
# Name: AU, dtype: object

# %%
df_full2.to_pickle("../data/dataframes/full_pubs.pkl")

# %%
df_full.to_csv("../data/dataframes/full_pubs.csv", sep="\t")

# %%
import pandas as pd
df_full = pd.read_csv("../data/dataframes/full_pubs.csv", sep='\t')
df_full
# Out:
#          Unnamed: 0 PT                                                 AU  \
# 0                 0  J               Gusiatin, ZM; Kulikowska, D; Klik, B
# 1                 1  J                              Vitko, TG; Suffet, IH
# 2                 2  C                             Ntasiou, M; Andreou, E
# 3                 3  J      Wu, LP; Zhang, SR; Chen, MM; Liu, J; Ding, XD
# 4                 4  C                                          Staicu, D
# ...             ... ..                                                ...
# 2798083     2798083  C  Dieffenderfer, J; Wilkins, M; Hood, C; Beppler...
# 2798084     2798084  C  Dinesh, K; Xiong, ML; Adams, J; Dorsey, R; Sha...
# 2798085     2798085  C    Ding, CW; Heidari, S; Wang, YZ; Liu, YP; Hu, JT
# 2798086     2798086  C        Ding, CW; Li, HJ; Hu, JT; Liu, YP; Wang, YZ
# 2798087     2798087  C                                  Ding, Y; Zilic, Z
#
#                                                         AF  \
# ...
