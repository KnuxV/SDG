# %%
import itertools

import numpy as np
import pandas as pd
import pickle
from collections import Counter
from tqdm import tqdm

# %%
df = pd.read_pickle("../data/dataframes/SDG/all_sdg_fixed_dst.pkl")

# %%
row = df.sample()

# %%
# Out:
# Int64Index([733162], dtype='int64')

# %%
row['ANN'] = 'analysis of stuff'

# %%
row
# Out:
#        PT           AU                                                 TI  \
# 733162  J  Roddick, AP  Temporalities of the Formative Period Taraco P...
#
#                                    SO  \
# 733162  JOURNAL OF SOCIAL ARCHAEOLOGY
#
#                                                       DE  \
# 733162  Andes; Bolivia; landscape; temporality; Tiwanaku
#
#                                                        AB  \
# 733162  Within the last 15 years archaeologists have d...
#
#                                                        C1  \
# 733162  McMaster Univ, Dept Anthropol, Hamilton, ON L8...
#
#                          EM  TC    PY  ... computing_infrastructure  \
# 733162  roddick@mcmaster.ca  12  2013  ...                    False
#
#        blockchain robotics additive_manufacturing Society Economy Environment  \
# 733162      False    False                  False    True   False       False
#
#            EU    DST                ANN
# ...

# %%
row.index[0] in df.index
# Out:
# True

# %%
df.columns[13:30]
# Out:
# Index(['SDG1', 'SDG2', 'SDG3', 'SDG4', 'SDG5', 'SDG6', 'SDG7', 'SDG8', 'SDG9',
#        'SDG10', 'SDG11', 'SDG12', 'SDG13', 'SDG14', 'SDG15', 'SDG16', 'SDG17'],
#       dtype='object')

# %%
df.columns[30:37]
# Out:
# Index(['AI', 'big_data', 'IOT', 'computing_infrastructure', 'blockchain',
#        'robotics', 'additive_manufacturing'],
#       dtype='object')

# %%
df_new = pd.read_pickle("../data/dataframes/SDG/annotated_df.pkl")

# %%
df_new
# Out:
#         PT                                                 AU  \
# 264661   J  De Giglio, M; Greggio, N; Goffo, F; Merloni, N...
# 292607   J  Connolly, RM; Fairclough, DV; Jinks, EL; Ditri...
# 155410   J  Rahmati, O; Falah, F; Dayal, KS; Deo, RC; Moha...
# 1012930  J                Ganguly, KK; Nahar, N; Hossain, BMM
# 928733   C  Nicolae, AA; Negru, C; Pop, F; Mocanu, M; Cris...
# 859695   J                           Yoon, I; Kim, H; Noh, DK
# 807635   C                                        Kral'ova, K
# 764233   J  Feng, Y; Huang, Z; Wang, YL; Wan, L; Liu, Y; Z...
# 784462   J                 Chen, L; Lu, JW; Song, ZJ; Zhou, J
# 850965   C                        Khan, D; Haopeng, C; Din, N
# 409920   C                   Sharma, L; Yadav, DK; Bharti, SK
# 814716   J                                    Park, J; Lim, Y
# 693508   J                Zhang, YL; Wei, YH; Pu, J; Yuan, XN
# 853397   J  Shi, YH; Huang, ZS; Oh, S; Kaslan, N; Song, J;...
# ...

# %%
df_new.loc[df_new['ANN']=='uu', "ANN"] = 'A'

# %%
df_new
# Out:
#         PT                                                 AU  \
# 264661   J  De Giglio, M; Greggio, N; Goffo, F; Merloni, N...
# 292607   J  Connolly, RM; Fairclough, DV; Jinks, EL; Ditri...
# 155410   J  Rahmati, O; Falah, F; Dayal, KS; Deo, RC; Moha...
# 1012930  J                Ganguly, KK; Nahar, N; Hossain, BMM
# 928733   C  Nicolae, AA; Negru, C; Pop, F; Mocanu, M; Cris...
# 859695   J                           Yoon, I; Kim, H; Noh, DK
# 807635   C                                        Kral'ova, K
# 764233   J  Feng, Y; Huang, Z; Wang, YL; Wan, L; Liu, Y; Z...
# 784462   J                 Chen, L; Lu, JW; Song, ZJ; Zhou, J
# 850965   C                        Khan, D; Haopeng, C; Din, N
# 409920   C                   Sharma, L; Yadav, DK; Bharti, SK
# 814716   J                                    Park, J; Lim, Y
# 693508   J                Zhang, YL; Wei, YH; Pu, J; Yuan, XN
# 853397   J  Shi, YH; Huang, ZS; Oh, S; Kaslan, N; Song, J;...
# ...
